# %% [markdown]
# <a href="https://colab.research.google.com/github/robertdc2/IS-170-Machine-Learning/blob/2.-Pandas-%26-Feature-Engineering/Sanchez_Fuentes_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba8bb9f1-bfbc-4a21-95cd-f79083a0e025" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba8bb9f1-bfbc-4a21-95cd-f79083a0e025">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("healthcare_data-2.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# 0                       0.627   50    severe
# ...

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72             35        0  33.6
# 1              1     85.0             66             29        0  26.6
# 2              8    183.0             64              0        0  23.3
# 3              1     89.0             66             23       94  28.1
# 4              0    137.0             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76             48      180  32.9
# 764            2    122.0             70             27        0  36.8
# 765            5    121.0             72             23      112  26.2
# 766            1    126.0             60              0        0  30.1
# 767            1     93.0             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# 0                       0.627   50    severe
# ...

# %%
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0             35        0  33.6
# 1              1     85.0           66.0             29        0  26.6
# 2              8    183.0           64.0              0        0  23.3
# 3              1     89.0           66.0             23       94  28.1
# 4              0    137.0           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0             48      180  32.9
# 764            2    122.0           70.0             27        0  36.8
# 765            5    121.0           72.0             23      112  26.2
# 766            1    126.0           60.0              0        0  30.1
# 767            1     93.0           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# 0                       0.627   50    severe
# ...

# %%
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000        0  33.6
# 1              1     85.0           66.0      29.000000        0  26.6
# 2              8    183.0           64.0      20.536458        0  23.3
# 3              1     89.0           66.0      23.000000       94  28.1
# 4              0    137.0           40.0      35.000000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000      180  32.9
# 764            2    122.0           70.0      27.000000        0  36.8
# 765            5    121.0           72.0      23.000000      112  26.2
# 766            1    126.0           60.0      20.536458        0  30.1
# 767            1     93.0           70.0      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# 0                       0.627   50    severe
# ...

# %%
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0             72             35   79.799479  33.6
# 1              1     85.0             66             29   79.799479  26.6
# 2              8    183.0             64              0   79.799479  23.3
# 3              1     89.0             66             23   94.000000  28.1
# 4              0    137.0             40             35  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0             76             48  180.000000  32.9
# 764            2    122.0             70             27   79.799479  36.8
# 765            5    121.0             72             23  112.000000  26.2
# 766            1    126.0             60              0   79.799479  30.1
# 767            1     93.0             70             31   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# ...

# %%
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0             72             35   79.799479  33.6
# 1              1     85.0             66             29   79.799479  26.6
# 2              8    183.0             64              0   79.799479  23.3
# 3              1     89.0             66             23   94.000000  28.1
# 4              0    137.0             40             35  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0             76             48  180.000000  32.9
# 764            2    122.0             70             27   79.799479  36.8
# 765            5    121.0             72             23  112.000000  26.2
# 766            1    126.0             60              0   79.799479  30.1
# 767            1     93.0             70             31   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# ...

# %%
df['Age']=df['Age'].replace(0,df['Age'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0             72             35   79.799479  33.6
# 1              1     85.0             66             29   79.799479  26.6
# 2              8    183.0             64              0   79.799479  23.3
# 3              1     89.0             66             23   94.000000  28.1
# 4              0    137.0             40             35  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0             76             48  180.000000  32.9
# 764            2    122.0             70             27   79.799479  36.8
# 765            5    121.0             72             23  112.000000  26.2
# 766            1    126.0             60              0   79.799479  30.1
# 767            1     93.0             70             31   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
label = le.fit_transform(df['Outcome'])
label
# Out:
# array([3, 1, 2, 1, 3, 0, 0, 0, 3, 0, 0, 3, 1, 1, 2, 0, 2, 0, 0, 0, 3, 1,
#        3, 0, 2, 2, 0, 3, 3, 0, 3, 2, 3, 1, 0, 3, 3, 0, 1, 2, 1, 3, 2, 2,
#        2, 2, 3, 1, 3, 1, 2, 2, 2, 0, 0, 1, 1, 0, 0, 0, 1, 1, 2, 1, 3, 3,
#        2, 1, 3, 0, 1, 0, 3, 0, 0, 2, 1, 3, 0, 0, 0, 1, 1, 2, 1, 3, 1, 3,
#        2, 1, 1, 1, 0, 0, 3, 0, 1, 3, 2, 3, 1, 1, 3, 3, 0, 1, 2, 3, 1, 2,
#        0, 2, 0, 3, 2, 3, 2, 3, 3, 2, 2, 3, 2, 2, 1, 3, 0, 3, 0, 2, 1, 2,
#        2, 3, 2, 0, 2, 3, 2, 3, 2, 3, 2, 0, 0, 0, 0, 3, 1, 0, 0, 1, 2, 3,
#        1, 3, 3, 2, 2, 0, 1, 0, 1, 1, 2, 1, 2, 2, 3, 1, 1, 2, 1, 2, 3, 3,
#        1, 0, 3, 3, 3, 3, 2, 1, 3, 2, 3, 1, 2, 3, 1, 3, 0, 1, 1, 1, 0, 0,
#        3, 3, 3, 0, 0, 1, 2, 1, 3, 1, 2, 3, 1, 0, 3, 2, 3, 0, 1, 0, 0, 3,
#        1, 0, 0, 1, 2, 3, 1, 2, 0, 1, 2, 2, 3, 1, 0, 0, 0, 1, 2, 3, 3, 0,
#        3, 3, 0, 0, 0, 2, 0, 3, 2, 0, 3, 3, 3, 1, 2, 0, 0, 2, 2, 3, 3, 2,
#        3, 1, 3, 1, 1, 3, 2, 0, 2, 2, 2, 1, 3, 3, 2, 3, 1, 3, 3, 3, 3, 0,
# ...

# %%
df.drop('Outcome', axis=1, inplace=True)
df['Outcome'] = label
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0             72             35   79.799479  33.6
# 1              1     85.0             66             29   79.799479  26.6
# 2              8    183.0             64              0   79.799479  23.3
# 3              1     89.0             66             23   94.000000  28.1
# 4              0    137.0             40             35  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0             76             48  180.000000  32.9
# 764            2    122.0             70             27   79.799479  36.8
# 765            5    121.0             72             23  112.000000  26.2
# 766            1    126.0             60              0   79.799479  30.1
# 767            1     93.0             70             31   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
from sklearn import preprocessing
df_scaled = preprocessing.scale(df)
df_scaled=pd.DataFrame(df_scaled,columns=df.columns)
df_scaled['Outcome'] = df['Outcome']
df=df_scaled

# %%
old_cols=df.columns.values
new_cols=['Age', 'BloodPressure', 'Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Outcome']
df=df.reindex(columns=new_cols)
df
# Out:
#           Age  BloodPressure  Pregnancies   Glucose  SkinThickness   Insulin  \
# 0    1.425995       0.149641     0.639947  0.865276            NaN -0.417768
# 1   -0.190672      -0.160546    -0.844885 -1.205989            NaN -0.417768
# 2   -0.105584      -0.263941     1.233880  2.015979            NaN -0.417768
# 3   -1.041549      -0.160546    -0.844885 -1.074480            NaN -0.265107
# 4   -0.020496      -1.504687    -1.141852  0.503626            NaN  0.530423
# ..        ...            ...          ...       ...            ...       ...
# 763  2.532136       0.356432     1.827813 -0.679954            NaN  0.659428
# 764 -0.531023       0.046245    -0.547919  0.010468            NaN -0.417768
# 765 -0.275760       0.149641     0.342981 -0.022409            NaN -0.071599
# 766  1.170732      -0.470732    -0.844885  0.141977            NaN -0.417768
# 767 -0.871374       0.046245    -0.844885 -0.942972            NaN -0.417768
#
# ...

# %%
print(df.rename(columns={'Glucose' : 'Sugar', 'SkinThickness': 'Skin'}))
# Out:
#           Age  BloodPressure  Pregnancies     Sugar  Skin   Insulin       BMI  \
# 0    1.425995       0.149641     0.639947  0.865276   NaN -0.417768  0.167255
# 1   -0.190672      -0.160546    -0.844885 -1.205989   NaN -0.417768 -0.851535
# 2   -0.105584      -0.263941     1.233880  2.015979   NaN -0.417768 -1.331821
# 3   -1.041549      -0.160546    -0.844885 -1.074480   NaN -0.265107 -0.633222
# 4   -0.020496      -1.504687    -1.141852  0.503626   NaN  0.530423  1.549899
# ..        ...            ...          ...       ...   ...       ...       ...
# 763  2.532136       0.356432     1.827813 -0.679954   NaN  0.659428  0.065376
# 764 -0.531023       0.046245    -0.547919  0.010468   NaN -0.417768  0.632988
# 765 -0.275760       0.149641     0.342981 -0.022409   NaN -0.071599 -0.909751
# 766  1.170732      -0.470732    -0.844885  0.141977   NaN -0.417768 -0.342140
# 767 -0.871374       0.046245    -0.844885 -0.942972   NaN -0.417768 -0.298477
#
# ...
