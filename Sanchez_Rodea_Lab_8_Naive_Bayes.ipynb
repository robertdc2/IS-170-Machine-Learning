# %% [markdown]
# <a href="https://colab.research.google.com/github/robertdc2/IS-170-Machine-Learning/blob/8.-Naive-Bayes/Sanchez_Rodea_Lab_8_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Robert Sanchez
# # Lab 8

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("/content/Naive-Bayes-Classification-Data.csv")
df
# Out:
#      glucose  bloodpressure  diabetes
# 0         40             85         0
# 1         40             92         0
# 2         45             63         1
# 3         45             80         0
# 4         40             73         1
# ..       ...            ...       ...
# 990       45             87         0
# 991       40             83         0
# 992       40             83         0
# 993       40             60         1
# 994       45             82         0
#
# [995 rows x 3 columns]

# %%
def merge (list1, list2):
  merged_list=tuple(zip(list1, list2))
  return merged_list

features=merge(df['glucose'], df['bloodpressure'])
features
# Out:
# ((40, 85),
#  (40, 92),
#  (45, 63),
#  (45, 80),
#  (40, 73),
#  (45, 82),
#  (40, 85),
#  (30, 63),
#  (65, 65),
#  (45, 82),
#  (35, 73),
#  (45, 90),
#  (50, 68),
#  (40, 93),
#  (35, 80),
#  (50, 70),
#  (40, 73),
#  (40, 67),
#  (40, 75),
#  (40, 80),
#  (40, 72),
#  (40, 88),
#  (40, 78),
#  (45, 98),
#  (40, 88),
#  (60, 67),
#  (40, 85),
#  (40, 88),
#  (45, 78),
#  (55, 73),
#  (45, 77),
#  (50, 68),
#  (45, 77),
#  (40, 85),
#  (45, 70),
#  (45, 72),
#  (45, 90),
#  (40, 65),
#  (45, 88),
#  (45, 88),
#  (40, 68),
#  (40, 73),
#  (45, 88),
#  (45, 78),
#  (45, 85),
#  (40, 83),
#  (40, 63),
#  (45, 73),
#  (45, 90),
#  (45, 87),
#  (40, 90),
#  (45, 93),
#  (50, 73),
#  (40, 68),
#  (50, 68),
#  (50, 90),
#  (50, 75),
#  (50, 85),
#  (45, 83),
#  (50, 65),
#  (45, 80),
#  (40, 75),
#  (35, 77),
#  (55, 68),
#  (45, 85),
#  (45, 87),
#  (25, 82),
#  (40, 90),
#  (45, 82),
#  (45, 80),
#  (45, 88),
#  (40, 87),
#  (45, 70),
#  (45, 88),
#  (45, 88),
#  (50, 67),
# ...

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
model = GaussianNB()

# Train the model using the training sets
model.fit(features,df['diabetes'])

#Predict Output
predicted= model.predict([[0,2]]) # 0:No Diabetes, 1: Has diabetes
print ("Predicted Value:", predicted)
# Out:
# Predicted Value: [1]

# %% [markdown]
# From the above result , 1 will indicate that the person does in fact have diabetes.

# %% [markdown]
# Dataset # 2 / Part 2
#
# Determining gender based on inputs.

# %%
df=pd.read_csv("/content/Adult Census Income.csv")
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
#In order to process we must turn those categorical values into numberic values
#Import LabelEncoder
from sklearn import preprocessing

#creating labelEncoder
le = preprocessing.LabelEncoder()

#Using .fit_transform function to fit label
#encoder and return encoded label
sex_label=le.fit_transform(df['sex'])
df.drop("sex", axis=1, inplace=True)
df["sex"] = sex_label

marital_label=le.fit_transform(df['marital.status'])
df.drop("marital.status", axis=1, inplace=True)
df["marital.status"] = marital_label

relationship_label=le.fit_transform(df['relationship'])
df.drop("relationship", axis=1, inplace=True)
df["relationship"] = relationship_label


df
# Out:
#        age workclass  fnlwgt     education  education.num         occupation  \
# 0       90         ?   77053       HS-grad              9                  ?
# 1       82   Private  132870       HS-grad              9    Exec-managerial
# 2       66         ?  186061  Some-college             10                  ?
# 3       54   Private  140359       7th-8th              4  Machine-op-inspct
# 4       41   Private  264663  Some-college             10     Prof-specialty
# ...    ...       ...     ...           ...            ...                ...
# 32556   22   Private  310152  Some-college             10    Protective-serv
# 32557   27   Private  257302    Assoc-acdm             12       Tech-support
# 32558   40   Private  154374       HS-grad              9  Machine-op-inspct
# 32559   58   Private  151910       HS-grad              9       Adm-clerical
# 32560   22   Private  201490       HS-grad              9       Adm-clerical
#
# ...

# %%
df.columns= ['age', 'workclass', 'fnlwgt', 'education', 'education.num', 'occupation', 'race', 'capital.gain','capital.loss','hours.per.week', 'native.country', 'income', 'sex', 'marital.status','relationship']
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num         occupation  \
# 0   90         ?   77053       HS-grad              9                  ?
# 1   82   Private  132870       HS-grad              9    Exec-managerial
# 2   66         ?  186061  Some-college             10                  ?
# 3   54   Private  140359       7th-8th              4  Machine-op-inspct
# 4   41   Private  264663  Some-college             10     Prof-specialty
#
#     race  capital.gain  capital.loss  hours.per.week native.country income  \
# 0  White             0          4356              40  United-States  <=50K
# 1  White             0          4356              18  United-States  <=50K
# 2  Black             0          4356              40  United-States  <=50K
# 3  White             0          3900              40  United-States  <=50K
# 4  White             0          3900              40  United-States  <=50K
#
#    sex  marital.status  relationship
# 0    1               6             1
# ...

# %%
#x_data = df[['age','education.num', 'fnlwgt', 'hours.per.week', 'marital.status','relationship']]
x_data = df[['age','education.num', 'hours.per.week', 'marital.status','relationship']]
y_data = df['sex']
#y_data = sex_label

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3,random_state=109) # 70% training and 30% test

# %%
#This is model generation

#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
model = GaussianNB()

#Train the model using the training sets
model.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)

#This is to evaluate the model
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# # Summary:
#
# Based on the model: If we enter the age, educuation level, hours per week the person works, their marital status, and their relationship status we can determine with 100% certainty whether they are male or female.
